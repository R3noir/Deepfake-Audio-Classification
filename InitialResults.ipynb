# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
audio_data = pd.read_csv("OpenSMILE_all_features.csv")
y = audio_data['label']
features = ['StddevUnvoicedSegmentLength', 'MeanUnvoicedSegmentLength']
X = audio_data[features]
X.head()
# Out:
#    StddevUnvoicedSegmentLength  MeanUnvoicedSegmentLength
# 0                     0.067593                   0.072500
# 1                     0.103773                   0.132500
# 2                     0.067185                   0.108333
# 3                     0.072930                   0.152500
# 4                     0.119117                   0.136667

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=42)

# %%
mapping = {'Deepfake': 0, 'Genuine': 1}
reverse_mapping = {v: k for k, v in mapping.items()}
print("Mapping:", mapping)
# Out:
# Mapping: {'Deepfake': 0, 'Genuine': 1}

# %%
#Random Forest
RF = RandomForestClassifier(random_state=42)
RF.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = RF.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        80
#            1       1.00      0.99      0.99        80
#
#     accuracy                           0.99       160
#    macro avg       0.99      0.99      0.99       160
# weighted avg       0.99      0.99      0.99       160

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))], yticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %%
DT = DecisionTreeClassifier(random_state=42)
DT.fit(X=X_train, y=y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = DT.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))], yticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %%
GBC = GradientBoostingClassifier(random_state=42)
GBC.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred = GBC.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))], yticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Gradient Boosting')
plt.show()

# %%
ETC = ExtraTreesClassifier(random_state=42)
ETC.fit(X=X_train, y=y_train)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
y_pred = ETC.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))], yticklabels=[reverse_mapping[i] for i in range(len(reverse_mapping))])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Extra Trees')
plt.show()
